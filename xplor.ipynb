# %%
import matplotlib.pyplot as plt
import numpy as np
import random

mu=3.0
sigma=0.5
lo=1.0
hi=4.75
N=10000
data=np.clip([random.gauss(mu, sigma) for _ in range(N)],lo,hi)
plt.hist(data, bins=100, density=True, alpha=0.6, color='g')
# Out:
# (array([0.00562368, 0.        , 0.00562368, 0.        , 0.        ,
#         0.00281184, 0.00562368, 0.        , 0.        , 0.00843552,
#         0.0140592 , 0.01687104, 0.0140592 , 0.01968288, 0.0281184 ,
#         0.0281184 , 0.0281184 , 0.05904864, 0.06467232, 0.08716704,
#         0.09560256, 0.09560256, 0.11809728, 0.12372096, 0.1265328 ,
#         0.15746304, 0.19682881, 0.21651169, 0.25868929, 0.21369985,
#         0.28118401, 0.29805505, 0.38522209, 0.40209313, 0.32054977,
#         0.46395361, 0.43583521, 0.56517985, 0.51456673, 0.60173378,
#         0.57080353, 0.66921794, 0.73107842, 0.68608898, 0.75638498,
#         0.71420738, 0.71701922, 0.75638498, 0.79575074, 0.75638498,
#         0.76763234, 0.8351165 , 0.69171266, 0.84355202, 0.76200866,
#         0.81824546, 0.84074018, 0.73951394, 0.75638498, 0.63547586,
#         0.6242285 , 0.51456673, 0.52581409, 0.57361537, 0.47520097,
#         0.43021153, 0.42458785, 0.36553921, 0.28961953, 0.33460897,
# ...
